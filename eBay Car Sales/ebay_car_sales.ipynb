# %% [markdown]
# # Exploring eBay Car Sales Data
#
# In this project I'll be cleaning, preparing, and researching used car sales data. The data is sourced from a German eBay site (*eBay Kleinanzeigan*).

# %%
import numpy as np
import pandas as pd

autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %% [markdown]
# Looks like we have a count of 50,000 rows and 20 columns to work with. I'm going to definitely make sure the `dateCrawled` index is in a consistent format. `name` will need to be broken down into make, model, and manufacturer (which looks synonymous with `brand`).

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
#        seller offerType    price   abtest vehicleType  yearOfRegistration  \
# 0      privat   Angebot   $5,000  control         bus                2004
# 1      privat   Angebot   $8,500  control   limousine                1997
# 2      privat   Angebot   $8,990     test   limousine                2009
# 3      privat   Angebot   $4,350  control  kleinwagen                2007
# 4      privat   Angebot   $1,350     test       kombi                2003
# ...       ...       ...      ...      ...         ...                 ...
# 49995  privat   Angebot  $24,900  control   limousine                2011
# 49996  privat   Angebot   $1,980  control      cabrio                1996
# 49997  privat   Angebot  $13,200     test      cabrio                2014
# 49998  privat   Angebot  $22,900  control       kombi                2013
# 49999  privat   Angebot   $1,250  control   limousine                1996
#
#          gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0        manuell      158  andere  150,000km                    3      lpg
# 1      automatik      286     7er  150,000km                    6   benzin
# 2        manuell      102    golf   70,000km                    7   benzin
# 3      automatik       71  fortwo   70,000km                    6   benzin
# 4        manuell        0   focus  150,000km                    7   benzin
# ...          ...      ...     ...        ...                  ...      ...
# 49995  automatik      239      q5  100,000km                    1   diesel
# 49996    manuell       75   astra  150,000km                    5   benzin
# 49997  automatik       69     500    5,000km                   11   benzin
# 49998    manuell      150      a3   40,000km                   11   diesel
# 49999    manuell      101  vectra  150,000km                    1   benzin
#
#             brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0         peugeot              nein  2016-03-26 00:00:00             0
# 1             bmw              nein  2016-04-04 00:00:00             0
# 2      volkswagen              nein  2016-03-26 00:00:00             0
# 3           smart              nein  2016-03-12 00:00:00             0
# 4            ford              nein  2016-04-01 00:00:00             0
# ...           ...               ...                  ...           ...
# 49995        audi              nein  2016-03-27 00:00:00             0
# 49996        opel              nein  2016-03-28 00:00:00             0
# 49997        fiat              nein  2016-04-02 00:00:00             0
# 49998        audi              nein  2016-03-08 00:00:00             0
# 49999        opel              nein  2016-03-13 00:00:00             0
#
#        postalCode             lastSeen
# 0           79588  2016-04-06 06:45:54
# 1           71034  2016-04-06 14:45:08
# 2           35394  2016-04-06 20:15:37
# 3           33729  2016-03-15 03:16:28
# 4           39218  2016-04-01 14:38:50
# ...           ...                  ...
# 49995       82131  2016-04-01 13:47:40
# 49996       44807  2016-04-02 14:18:02
# 49997       73430  2016-04-04 11:47:27
# 49998       35683  2016-04-05 16:45:07
# 49999       45897  2016-04-06 21:18:48
#
# [50000 rows x 20 columns]

# %% [markdown]
# Columns `price` and `odometer` will need to be converted to `int64` or `float64` as needed. It will also be nice to change all our column headers to a more consistently pythonic version. There is also quite a bit of missing info in certain columns (particularly `notRepairedDamage`).

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
#  15  notRepairedDamage    40171 non-null  object
#  16  dateCreated          50000 non-null  object
#  17  nrOfPictures         50000 non-null  int64
#  18  postalCode           50000 non-null  int64
#  19  lastSeen             50000 non-null  object
# dtypes: int64(5), object(15)
# memory usage: 7.6+ MB

# %% [markdown]
# **Did Pandas add an index column or do I need to do that?**

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# 0    manuell      158  andere  150,000km                    3      lpg
# 1  automatik      286     7er  150,000km                    6   benzin
# 2    manuell      102    golf   70,000km                    7   benzin
# 3  automatik       71  fortwo   70,000km                    6   benzin
# 4    manuell        0   focus  150,000km                    7   benzin
#
#         brand notRepairedDamage          dateCreated  nrOfPictures  \
# 0     peugeot              nein  2016-03-26 00:00:00             0
# 1         bmw              nein  2016-04-04 00:00:00             0
# 2  volkswagen              nein  2016-03-26 00:00:00             0
# 3       smart              nein  2016-03-12 00:00:00             0
# 4        ford              nein  2016-04-01 00:00:00             0
#
#    postalCode             lastSeen
# 0       79588  2016-04-06 06:45:54
# 1       71034  2016-04-06 14:45:08
# 2       35394  2016-04-06 20:15:37
# 3       33729  2016-03-15 03:16:28
# 4       39218  2016-04-01 14:38:50

# %% [markdown]
# Columns are `camelCase` and not our lovely, Pythonic `snakecase`. We'll also convert oddly named columns like `nrOfPictures` to `picture_count` and the ambiguous `dateCreated` to `ad_created`.

# %%
mapping_col_dict = {'dateCrawled': 'date_crawled',
                    'offerType': 'offer_type',
                    'vehicleType': 'vehicle_type',
                    'yearOfRegistration': 'registration_year',
                    'powerPS': 'power_ps',
                    'monthOfRegistration': 'registration_month',
                    'fuelType': 'fuel_type',
                    'notRepairedDamage': 'unrepaired_damage',
                    'dateCreated': 'ad_created',
                    'nrOfPictures': 'picture_count',
                    'postalCode': 'postal_code',
                    'lastSeen': 'last_seen'
                   }

autos = autos.rename(mapping_col_dict, axis="columns")

autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# 0    manuell       158  andere  150,000km                   3       lpg
# 1  automatik       286     7er  150,000km                   6    benzin
# 2    manuell       102    golf   70,000km                   7    benzin
# 3  automatik        71  fortwo   70,000km                   6    benzin
# 4    manuell         0   focus  150,000km                   7    benzin
#
#         brand unrepaired_damage           ad_created  picture_count  \
# 0     peugeot              nein  2016-03-26 00:00:00              0
# 1         bmw              nein  2016-04-04 00:00:00              0
# 2  volkswagen              nein  2016-03-26 00:00:00              0
# 3       smart              nein  2016-03-12 00:00:00              0
# 4        ford              nein  2016-04-01 00:00:00              0
#
#    postal_code            last_seen
# 0        79588  2016-04-06 06:45:54
# 1        71034  2016-04-06 14:45:08
# 2        35394  2016-04-06 20:15:37
# 3        33729  2016-03-15 03:16:28
# 4        39218  2016-04-01 14:38:50

# %% [markdown]
# Much better! :)

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-04-02 11:37:04  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# count         44905       50000.000000    47320  50000.000000  47242
# unique            8                NaN        2           NaN    245
# top       limousine                NaN  manuell           NaN   golf
# freq          12859                NaN    36993           NaN   4024
# mean            NaN        2005.073280      NaN    116.355920    NaN
# std             NaN         105.712813      NaN    209.216627    NaN
# min             NaN        1000.000000      NaN      0.000000    NaN
# 25%             NaN        1999.000000      NaN     70.000000    NaN
# 50%             NaN        2003.000000      NaN    105.000000    NaN
# 75%             NaN        2008.000000      NaN    150.000000    NaN
# max             NaN        9999.000000      NaN  17700.000000    NaN
#
#          odometer  registration_month fuel_type       brand unrepaired_damage  \
# count       50000        50000.000000     45518       50000             40171
# unique         13                 NaN         7          40                 2
# top     150,000km                 NaN    benzin  volkswagen              nein
# freq        32424                 NaN     30107       10687             35232
# mean          NaN            5.723360       NaN         NaN               NaN
# std           NaN            3.711984       NaN         NaN               NaN
# min           NaN            0.000000       NaN         NaN               NaN
# 25%           NaN            3.000000       NaN         NaN               NaN
# 50%           NaN            6.000000       NaN         NaN               NaN
# 75%           NaN            9.000000       NaN         NaN               NaN
# max           NaN           12.000000       NaN         NaN               NaN
#
#                  ad_created  picture_count   postal_code            last_seen
# count                 50000        50000.0  50000.000000                50000
# unique                   76            NaN           NaN                39481
# top     2016-04-03 00:00:00            NaN           NaN  2016-04-07 06:17:27
# freq                   1946            NaN           NaN                    8
# mean                    NaN            0.0  50813.627300                  NaN
# std                     NaN            0.0  25779.747957                  NaN
# min                     NaN            0.0   1067.000000                  NaN
# 25%                     NaN            0.0  30451.000000                  NaN
# 50%                     NaN            0.0  49577.000000                  NaN
# 75%                     NaN            0.0  71540.000000                  NaN
# max                     NaN            0.0  99998.000000                  NaN

# %%
autos[~(autos['seller'] == 'privat')]
# Out:
#              date_crawled                                         name  \
# 7738  2016-03-15 18:06:22  Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
#
#           seller offer_type price   abtest vehicle_type  registration_year  \
# 7738  gewerblich    Angebot  $100  control        kombi               2000
#
#       gearbox  power_ps   model   odometer  registration_month fuel_type  \
# 7738  manuell         0  megane  150,000km                   8    benzin
#
#         brand unrepaired_damage           ad_created  picture_count  \
# 7738  renault               NaN  2016-03-15 00:00:00              0
#
#       postal_code            last_seen
# 7738        65232  2016-04-06 17:15:37

# %%
autos[~(autos['offer_type'] == 'Angebot')]
# Out:
#               date_crawled                  name  seller offer_type price  \
# 17541  2016-04-03 15:48:33  Suche_VW_T5_Multivan  privat     Gesuch    $0
#
#       abtest vehicle_type  registration_year gearbox  power_ps        model  \
# 17541   test          bus               2005     NaN         0  transporter
#
#         odometer  registration_month fuel_type       brand unrepaired_damage  \
# 17541  150,000km                   0       NaN  volkswagen               NaN
#
#                 ad_created  picture_count  postal_code            last_seen
# 17541  2016-04-03 00:00:00              0        29690  2016-04-05 15:16:06

# %%
autos[~(autos['unrepaired_damage'] == 'nein')]
# Out:
#               date_crawled                                               name  \
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 11     2016-03-16 18:45:34                         Mercedes_A140_Motorschaden
# 14     2016-03-23 11:50:46  Renault_Clio_3__Dynamique_1.2__16_V;_viele_Ver...
# 18     2016-03-26 19:57:44               Verkaufen_mein_bmw_e36_320_i_touring
# ...                    ...                                                ...
# 49984  2016-03-31 22:48:48  Student_sucht_ein__Anfaengerauto___ab_2000_BJ_...
# 49985  2016-04-02 16:38:23                          Verkaufe_meinen_vw_vento!
# 49989  2016-03-11 19:50:37        VW_Polo_zum_Ausschlachten_oder_Wiederaufbau
# 49991  2016-03-06 15:25:19                                         Kleinwagen
# 49993  2016-03-15 18:47:35           Audi_A3__1_8l__Silber;_schoenes_Fahrzeug
#
#        seller offer_type   price   abtest vehicle_type  registration_year  \
# 5      privat    Angebot  $7,900     test          bus               2006
# 6      privat    Angebot    $300     test    limousine               1995
# 11     privat    Angebot    $350  control          NaN               2000
# 14     privat    Angebot  $3,999     test   kleinwagen               2007
# 18     privat    Angebot    $300  control          bus               1995
# ...       ...        ...     ...      ...          ...                ...
# 49984  privat    Angebot      $0     test          NaN               2000
# 49985  privat    Angebot  $1,000  control          NaN               1995
# 49989  privat    Angebot    $150     test   kleinwagen               1997
# 49991  privat    Angebot    $500  control          NaN               2016
# 49993  privat    Angebot  $1,650  control   kleinwagen               1997
#
#          gearbox  power_ps    model   odometer  registration_month fuel_type  \
# 5      automatik       150  voyager  150,000km                   4    diesel
# 6        manuell        90     golf  150,000km                   8    benzin
# 11           NaN         0      NaN  150,000km                   0    benzin
# 14       manuell        75     clio  150,000km                   9    benzin
# 18       manuell       150      3er  150,000km                   0    benzin
# ...          ...       ...      ...        ...                 ...       ...
# 49984        NaN         0      NaN  150,000km                   0       NaN
# 49985  automatik         0      NaN  150,000km                   0    benzin
# 49989    manuell         0     polo  150,000km                   5    benzin
# 49991    manuell         0   twingo  150,000km                   0    benzin
# 49993    manuell         0      NaN  150,000km                   7    benzin
#
#                 brand unrepaired_damage           ad_created  picture_count  \
# 5            chrysler               NaN  2016-03-21 00:00:00              0
# 6          volkswagen               NaN  2016-03-20 00:00:00              0
# 11      mercedes_benz               NaN  2016-03-16 00:00:00              0
# 14            renault               NaN  2016-03-23 00:00:00              0
# 18                bmw               NaN  2016-03-26 00:00:00              0
# ...               ...               ...                  ...            ...
# 49984  sonstige_autos               NaN  2016-03-31 00:00:00              0
# 49985      volkswagen               NaN  2016-04-02 00:00:00              0
# 49989      volkswagen                ja  2016-03-11 00:00:00              0
# 49991         renault               NaN  2016-03-06 00:00:00              0
# 49993            audi               NaN  2016-03-15 00:00:00              0
#
#        postal_code            last_seen
# 5            22962  2016-04-06 09:45:21
# 6            31535  2016-03-23 02:48:59
# 11           17498  2016-03-16 18:45:34
# 14           81737  2016-04-01 15:46:47
# 18           54329  2016-04-02 12:16:41
# ...            ...                  ...
# 49984        12103  2016-04-02 19:44:53
# 49985        30900  2016-04-06 15:17:52
# 49989        21244  2016-03-12 10:17:55
# 49991        61350  2016-03-06 18:24:19
# 49993        65203  2016-04-06 19:46:53
#
# [14768 rows x 20 columns]

# %% [markdown]
# Taking a closer look at the data that needs cleaning.
# `seller` and `offer_type` only have two unique entries. One of them has 49,999 occurences. We can probably drop these columns altogether.
# `unrepaired_damage` has three different entry types. That will require more investigation.
# `registration_year`, `power_ps`, `postal_code`, and `picture_count` need to be converted to `int`.
# `price` and `odometer` are currently string objects. They need to be stripped of `$` and converted to `int`.
# All the date specific columns have a date format. Gonna have to make sure those become the correct `dtype`.
# `registration_month` has values of 1000 and 9999. Those are certianly not years that are possible.

# %% [markdown]
# ### `price` and `odometer`

# %% [markdown]
# **Clean `price` column, convert to `int64`.**
# `dtype` for `value_count` being `int64` refers to the `value_count` as it's OWN object.

# %%
print(autos["price"].value_counts())
print(autos["price"].describe())
# Out:
# $0         1421
# $500        781
# $1,500      734
# $2,500      643
# $1,000      639
#            ...
# $414          1
# $79,933       1
# $5,198        1
# $18,890       1
# $16,995       1
# Name: price, Length: 2357, dtype: int64
# count     50000
# unique     2357
# top          $0
# freq       1421
# Name: price, dtype: object

# %%
autos["price"] = autos["price"].str.replace('$', '', regex=False).str.replace(',', '', regex=False).astype(int)
autos["price"].value_counts()
# Out:
# 0        1421
# 500       781
# 1500      734
# 2500      643
# 1000      639
#          ...
# 414         1
# 79933       1
# 5198        1
# 18890       1
# 16995       1
# Name: price, Length: 2357, dtype: int64

# %% [markdown]
# **Clean `odometer` column, convert to `int64`.**
# Rename column as `odometer_km`.

# %%
print(autos["odometer"].value_counts())
print(autos["odometer"].describe())
# Out:
# 150,000km    32424
# 125,000km     5170
# 100,000km     2169
# 90,000km      1757
# 80,000km      1436
# 70,000km      1230
# 60,000km      1164
# 50,000km      1027
# 5,000km        967
# 40,000km       819
# 30,000km       789
# 20,000km       784
# 10,000km       264
# Name: odometer, dtype: int64
# count         50000
# unique           13
# top       150,000km
# freq          32424
# Name: odometer, dtype: object

# %%
autos["odometer"] = autos["odometer"].str.replace('km', '', regex=False).str.replace(',', '', regex=False).astype(int)
autos.rename({"odometer": "odometer_km"}, axis=1, inplace=True)

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %% [markdown]
# Let's continue exploring the data, specifically looking for data that doesn't look right. We'll start by analyzing the `odometer_km` and `price` columns.

# %%
prices = autos["price"]

# print(prices.unique().shape, '\n')
# print(prices.describe(), '\n')
# print(prices.value_counts().head().sort_index(ascending=False), '\n')
# print(prices.value_counts().head(25).sort_index(ascending=True), '\n')
# print(prices.value_counts().sort_index(ascending=False).head(), '\n')

print(prices.value_counts(bins=[0, 1, 100, 1000, 5000, 10000, 50000, 150000, 99999999]).sort_index(), '\n')
# Out:
# (-0.001, 1.0]              1577
# (1.0, 100.0]                319
# (100.0, 1000.0]           10103
# (1000.0, 5000.0]          20993
# (5000.0, 10000.0]          8935
# (10000.0, 50000.0]         7873
# (50000.0, 150000.0]         166
# (150000.0, 99999999.0]       34
# Name: price, dtype: int64

# %%
odometers = autos["odometer_km"]

# print(odometers.unique().shape, '\n')
# print(odometers.describe(), '\n')
print(odometers.value_counts().sort_index(ascending=True).head(25), '\n')
print(odometers.value_counts(bins=[0, 4999, 50000, 100000, 150000, 300000]).sort_index(), '\n')
# Out:
# 5000        967
# 10000       264
# 20000       784
# 30000       789
# 40000       819
# 50000      1027
# 60000      1164
# 70000      1230
# 80000      1436
# 90000      1757
# 100000     2169
# 125000     5170
# 150000    32424
# Name: odometer_km, dtype: int64
#
# (-0.001, 4999.0]            0
# (4999.0, 50000.0]        4650
# (50000.0, 100000.0]      7756
# (100000.0, 150000.0]    37594
# (150000.0, 300000.0]        0
# Name: odometer_km, dtype: int64

# %% [markdown]
# ### `last_seen`, `ad_created`, and `last_seen`

# %%
autos[['date_crawled', 'ad_created', 'last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
print(autos['date_crawled'].str[:10])
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
#             ...
# 49995    2016-03-27
# 49996    2016-03-28
# 49997    2016-04-02
# 49998    2016-03-08
# 49999    2016-03-14
# Name: date_crawled, Length: 50000, dtype: object

# %%
date_crawled = autos['date_crawled'].str[:10]
date_crawled.value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.02538
# 2016-03-06    0.01394
# 2016-03-07    0.03596
# 2016-03-08    0.03330
# 2016-03-09    0.03322
# 2016-03-10    0.03212
# 2016-03-11    0.03248
# 2016-03-12    0.03678
# 2016-03-13    0.01556
# 2016-03-14    0.03662
# 2016-03-15    0.03398
# 2016-03-16    0.02950
# 2016-03-17    0.03152
# 2016-03-18    0.01306
# 2016-03-19    0.03490
# 2016-03-20    0.03782
# 2016-03-21    0.03752
# 2016-03-22    0.03294
# 2016-03-23    0.03238
# 2016-03-24    0.02910
# 2016-03-25    0.03174
# 2016-03-26    0.03248
# 2016-03-27    0.03104
# 2016-03-28    0.03484
# 2016-03-29    0.03418
# 2016-03-30    0.03362
# 2016-03-31    0.03192
# 2016-04-01    0.03380
# 2016-04-02    0.03540
# 2016-04-03    0.03868
# 2016-04-04    0.03652
# 2016-04-05    0.01310
# 2016-04-06    0.00318
# 2016-04-07    0.00142
# Name: date_crawled, dtype: float64

# %% [markdown]
# *It appears that this was all taken from a period of four weeks.*

# %%
ad_created = autos['ad_created'].str[:10]
ad_created.value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2015-06-11    0.00002
# 2015-08-10    0.00002
# 2015-09-09    0.00002
# 2015-11-10    0.00002
# 2015-12-05    0.00002
#                ...
# 2016-04-03    0.03892
# 2016-04-04    0.03688
# 2016-04-05    0.01184
# 2016-04-06    0.00326
# 2016-04-07    0.00128
# Name: ad_created, Length: 76, dtype: float64

# %% [markdown]
# *Ads were created as far back as 2015 June to our most recent 2016 April.*

# %%
last_seen = autos['last_seen'].str[:10]
last_seen.value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.00108
# 2016-03-06    0.00442
# 2016-03-07    0.00536
# 2016-03-08    0.00760
# 2016-03-09    0.00986
# 2016-03-10    0.01076
# 2016-03-11    0.01252
# 2016-03-12    0.02382
# 2016-03-13    0.00898
# 2016-03-14    0.01280
# 2016-03-15    0.01588
# 2016-03-16    0.01644
# 2016-03-17    0.02792
# 2016-03-18    0.00742
# 2016-03-19    0.01574
# 2016-03-20    0.02070
# 2016-03-21    0.02074
# 2016-03-22    0.02158
# 2016-03-23    0.01858
# 2016-03-24    0.01956
# 2016-03-25    0.01920
# 2016-03-26    0.01696
# 2016-03-27    0.01602
# 2016-03-28    0.02086
# 2016-03-29    0.02234
# 2016-03-30    0.02484
# 2016-03-31    0.02384
# 2016-04-01    0.02310
# 2016-04-02    0.02490
# 2016-04-03    0.02536
# 2016-04-04    0.02462
# 2016-04-05    0.12428
# 2016-04-06    0.22100
# 2016-04-07    0.13092
# Name: last_seen, dtype: float64

# %% [markdown]
# *Something was happening on 2016-04-06 to cause a spike in last seen view count.*

# %% [markdown]
# ### `registration_year`

# %%
autos["registration_year"].describe()
# Out:
# count    50000.000000
# mean      2005.073280
# std        105.712813
# min       1000.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The `registration_year` column has values ranging `1000` to `9999`. A car can't be registered after the date of the listing (2016). So these are incorrect.
# As for the other direction, it's fairly improbable for a car to have been registered before the first few decades of the 1900s. So we'll take a look at the rows outside `1900-2016` and see if we can just drop these rows.

# %%
reg_year = autos["registration_year"]

pre_1900 = autos[reg_year < 1900]
# pre_1900.describe(include='all')

pre_1900
# Out:
#               date_crawled                                              name  \
# 10556  2016-04-01 06:02:10                                        UNFAL_Auto
# 22316  2016-03-29 16:56:41             VW_Kaefer.__Zwei_zum_Preis_von_einem.
# 24511  2016-03-17 19:45:11                       Trabant__wartburg__Ostalgie
# 32585  2016-04-02 16:56:39                                        UNFAL_Auto
# 35238  2016-03-26 13:45:20  Suche_Skoda_Fabia____Skoda_Fabia_Combi_mit_Klima
# 49283  2016-03-15 18:38:53                                        Citroen_HY
#
#        seller offer_type  price   abtest vehicle_type  registration_year  \
# 10556  privat    Angebot    450  control          NaN               1800
# 22316  privat    Angebot   1500  control          NaN               1000
# 24511  privat    Angebot    490  control          NaN               1111
# 32585  privat    Angebot    450  control          NaN               1800
# 35238  privat    Angebot      0  control          NaN               1500
# 49283  privat    Angebot   7750  control          NaN               1001
#
#        gearbox  power_ps   model  odometer_km  registration_month fuel_type  \
# 10556      NaN      1800     NaN         5000                   2       NaN
# 22316  manuell         0  kaefer         5000                   0    benzin
# 24511      NaN         0     NaN         5000                   0       NaN
# 32585      NaN      1800     NaN         5000                   2       NaN
# 35238      NaN         0     NaN         5000                   0    benzin
# 49283      NaN         0  andere         5000                   0       NaN
#
#             brand unrepaired_damage           ad_created  picture_count  \
# 10556  mitsubishi              nein  2016-04-01 00:00:00              0
# 22316  volkswagen               NaN  2016-03-29 00:00:00              0
# 24511     trabant               NaN  2016-03-17 00:00:00              0
# 32585  mitsubishi              nein  2016-04-02 00:00:00              0
# 35238       skoda               NaN  2016-03-26 00:00:00              0
# 49283     citroen               NaN  2016-03-15 00:00:00              0
#
#        postal_code            last_seen
# 10556        63322  2016-04-01 09:42:30
# 22316        48324  2016-03-31 10:15:28
# 24511        16818  2016-04-07 07:17:29
# 32585        63322  2016-04-04 14:46:21
# 35238        15517  2016-04-04 00:16:54
# 49283        66706  2016-04-06 18:47:20

# %% [markdown]
# Only 6 rows before 1900. There are `NaN` values for `vehicle_type` and`gearbox`, and odometer readings that make no sense. Also these rows are claiming they were registered before the companies were even founded.

# %%
post_2016 = autos[reg_year > 2016]
post_2016.describe(include='all')
# Out:
#                date_crawled        name  seller offer_type         price  \
# count                  1966        1966    1966       1966  1.966000e+03
# unique                 1963        1901       1          1           NaN
# top     2016-03-29 20:38:23  Ford_Focus  privat    Angebot           NaN
# freq                      2           5    1966       1966           NaN
# mean                    NaN         NaN     NaN        NaN  1.608905e+04
# std                     NaN         NaN     NaN        NaN  3.935826e+05
# min                     NaN         NaN     NaN        NaN  0.000000e+00
# 25%                     NaN         NaN     NaN        NaN  9.500000e+02
# 50%                     NaN         NaN     NaN        NaN  1.950000e+03
# 75%                     NaN         NaN     NaN        NaN  4.450000e+03
# max                     NaN         NaN     NaN        NaN  1.234568e+07
#
#        abtest vehicle_type  registration_year  gearbox      power_ps model  \
# count    1966            2        1966.000000     1715   1966.000000  1680
# unique      2            2                NaN        2           NaN   181
# top      test        coupe                NaN  manuell           NaN  golf
# freq     1000            1                NaN     1432           NaN   209
# mean      NaN          NaN        2062.464395      NaN     97.425229   NaN
# std       NaN          NaN         527.272473      NaN    423.857393   NaN
# min       NaN          NaN        2017.000000      NaN      0.000000   NaN
# 25%       NaN          NaN        2017.000000      NaN      0.000000   NaN
# 50%       NaN          NaN        2017.000000      NaN     75.000000   NaN
# 75%       NaN          NaN        2018.000000      NaN    120.000000   NaN
# max       NaN          NaN        9999.000000      NaN  16011.000000   NaN
#
#           odometer_km  registration_month fuel_type       brand  \
# count     1966.000000         1966.000000      1215        1966
# unique            NaN                 NaN         5          40
# top               NaN                 NaN    benzin  volkswagen
# freq              NaN                 NaN       857         498
# mean    130707.019329            4.654120       NaN         NaN
# std      37583.611576            3.912061       NaN         NaN
# min       5000.000000            0.000000       NaN         NaN
# 25%     125000.000000            1.000000       NaN         NaN
# 50%     150000.000000            4.000000       NaN         NaN
# 75%     150000.000000            8.000000       NaN         NaN
# max     150000.000000           12.000000       NaN         NaN
#
#        unrepaired_damage           ad_created  picture_count   postal_code  \
# count               1129                 1966         1966.0   1966.000000
# unique                 2                   39            NaN           NaN
# top                 nein  2016-03-28 00:00:00            NaN           NaN
# freq                 975                   80            NaN           NaN
# mean                 NaN                  NaN            0.0  47843.092574
# std                  NaN                  NaN            0.0  25312.288972
# min                  NaN                  NaN            0.0   1067.000000
# 25%                  NaN                  NaN            0.0  27592.000000
# 50%                  NaN                  NaN            0.0  45967.000000
# 75%                  NaN                  NaN            0.0  66129.250000
# max                  NaN                  NaN            0.0  99974.000000
#
#                   last_seen
# count                  1966
# unique                 1951
# top     2016-04-07 09:46:25
# freq                      2
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
# Remove the rows outside 1900-2016.
autos = autos[autos["registration_year"].between(1900, 2016)]

autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  4.802800e+04        48028.00000  48028.000000   48028.000000
# mean   9.585252e+03         2002.80351    117.070417  125544.161739
# std    4.843817e+05            7.31085    195.151278   40106.751417
# min    0.000000e+00         1910.00000      0.000000    5000.000000
# 25%    1.150000e+03         1999.00000     71.000000  100000.000000
# 50%    2.990000e+03         2003.00000    107.000000  150000.000000
# 75%    7.400000e+03         2008.00000    150.000000  150000.000000
# max    1.000000e+08         2016.00000  17700.000000  150000.000000
#
#        registration_month  picture_count   postal_code
# count        48028.000000        48028.0  48028.000000
# mean             5.767760            0.0  50935.867327
# std              3.696802            0.0  25792.079828
# min              0.000000            0.0   1067.000000
# 25%              3.000000            0.0  30459.000000
# 50%              6.000000            0.0  49696.000000
# 75%              9.000000            0.0  71665.000000
# max             12.000000            0.0  99998.000000

# %% [markdown]
# We removed 1972 rows from 50,000 leaving us 48028. Our ranges seem far more plausible now. With the vast majority beteween `1999-2008`.

# %%
autos["registration_year"].value_counts(normalize=True).sort_index()
# Out:
# 1910    0.000187
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000042
#           ...
# 2012    0.027546
# 2013    0.016782
# 2014    0.013867
# 2015    0.008308
# 2016    0.027401
# Name: registration_year, Length: 78, dtype: float64

# %% [markdown]
# ### `brand`

# %%
brands = autos["brand"]
brands.value_counts()
# Out:
# volkswagen        10188
# bmw                5284
# opel               5195
# mercedes_benz      4580
# audi               4149
# ford               3352
# renault            2274
# peugeot            1418
# fiat               1242
# seat                873
# skoda               770
# mazda               727
# nissan              725
# citroen             669
# smart               668
# toyota              599
# sonstige_autos      526
# hyundai             473
# volvo               444
# mini                415
# mitsubishi          391
# honda               377
# kia                 341
# alfa_romeo          318
# porsche             293
# suzuki              284
# chevrolet           274
# chrysler            176
# daihatsu            123
# dacia               123
# jeep                108
# subaru              105
# land_rover           98
# saab                 77
# jaguar               76
# trabant              75
# daewoo               72
# rover                65
# lancia               52
# lada                 29
# Name: brand, dtype: int64

# %% [markdown]
# It looks like the top brand is volkswagen by a lot. The following big dogs are bmw, opel, mercedes_benz and audi. I'm going to start by just seeing what the mean price for volkswagens has been.

# %%
# bmw = autos[autos['brand'] == 'bmw']
# print(bmw['price'].mean())

# lada = autos[autos['brand'] == 'lada']
# # lada.describe(include='all')
# print(lada['price'].mean())

top_brand_avg = {}

top_20_brands = autos["brand"].value_counts().index[:20]

for b in top_20_brands:
    brand = autos[autos['brand'] == b]
    mean_price = brand['price'].mean()
    top_brand_avg[b] = mean_price


pd.DataFrame.from_dict(top_brand_avg, orient='index')
# Out:
#                            0
# volkswagen       6516.457597
# bmw              8334.645155
# opel             5252.616554
# mercedes_benz   30317.447817
# audi             9093.650036
# ford             7263.015811
# renault          2395.416447
# peugeot          3039.468265
# fiat             2711.801127
# seat             4296.492554
# skoda            6334.919481
# mazda            4010.771664
# nissan           4664.891034
# citroen         44534.796712
# smart            3542.706587
# toyota           5115.333890
# sonstige_autos  39621.779468
# hyundai          5308.539112
# volvo            4757.108108
# mini            10460.012048

# %% [markdown]
# After looking at the mean car prices for the top 20 most listed brands it looks like you could easily find a VW for around 6500.
# The major outliers bein Mercedes, Citroen, and Sonstige with price 30,000 and up.
# The most affordable car would be a Fiat.

# %% [markdown]
# ## Something ain't right above. Check it tomorrow.

# %% [markdown]
# I'm going to start by dropping the useless columns containing 99.99% the same data.

# %%
# autos.drop(['seller', 'offer_type', 'unrepaired_damage'], axis=1, inplace=True)

# autos.describe(include='all')
